# %%
from sklearn.datasets import make_blobs
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = make_blobs(n_samples=200,centers=2,random_state=8)
X,y=data
plt.scatter(X[:,0],X[:,1],c=y,cmap=plt.cm.spring,edgecolor='k')
plt.show()

# %%
import numpy as np

# %%
clf = KNeighborsClassifier()
clf.fit(X,y)
x_min,x_max = X[:,0].min()-1, X[:,0].max()+1
y_min,y_max = X[:,1].min()-1, X[:,1].max()+1
xx,yy = np.meshgrid(np.arange(x_min,x_max,.02),np.arange(y_min,y_max,.02))
z = clf.predict(np.c_[xx.ravel(),yy.ravel()])
z = z.reshape(xx.shape)
plt.pcolormesh(xx,yy,z,cmap=plt.cm.Pastel1)
plt.scatter(X[:,0],X[:,1],c=y,cmap=plt.cm.spring,edgecolor='k')
plt.xlim(xx.min(),xx.max())
plt.ylim(yy.min(),yy.max())
plt.title("Classifier:KNN")
plt.scatter(6.75,4.82,marker ='*', c='red',s=200)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.

# %%
print('\n\n\n')
print('results from code:')
print('===========================')
print('new data class is:',clf.predict([[6.75,4.82]]))
print('===========================')
print('\n\n\n')
# Out:
# results from code:
# ...
# new data class is: [1]
# ...

# %%
data2 = make_blobs(n_samples = 500, centers = 5, random_state=8)
x2,y2=data2
plt.scatter(x2[:,0],x2[:,1],c=y2,cmap=plt.cm.spring,edgecolor='k')
plt.show()

# %%
clf = KNeighborsClassifier()
clf.fit(x2,y2)
x_min,x_max = x2[:,0].min()-1,x2[:,0].max()+1
y_min,y_max = x2[:,1].min()-1,x2[:,1].max()+1
xx,yy = np.meshgrid(np.arange(x_min,x_max,.02),np.arange(y_min,y_max,.02))
Z=clf.predict(np.c_[xx.ravel(),yy.ravel()])
Z=Z.reshape(xx.shape)
plt.pcolormesh(xx,yy,Z,cmap=plt.cm.Pastel1)
plt.scatter(x2[:,0],x2[:,1],c=y2,cmap=plt.cm.spring,edgecolor='k')
plt.xlim(xx.min(),xx.max())
plt.ylim(yy.min(),yy.max())
plt.title("Classifier:KNN 2")
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.

# %%
print('\n\n\n')
print('result:')
print('======================')
print('accuracy: {:.2f}'.format(clf.score(x2,y2)))
print('======================')
print('\n\n\n')
# Out:
# result:
# ...
# accuracy: 0.96
# ...

# %%
from sklearn.datasets import make_regression
X,y = make_regression(n_features=1,n_informative=1,noise=50,random_state=8)
plt.scatter(X,y,c='orange',edgecolor='k')
plt.show()

# %%
from sklearn.neighbors import KNeighborsRegressor
reg = KNeighborsRegressor()
reg.fit(X,y)
z=np.linspace(-3,3,200).reshape(-1,1)
plt.scatter(X,y,c='orange',edgecolor = 'k')
plt.plot(z,reg.predict(z),c='k',linewidth=3)
plt.title('KNN Regressor')
plt.show()

# %%
print('\n\n\n')
print('=======================')
print('Accuracy: {:.2f}'.format(reg.score(X,y)))
print('=======================')
print('\n\n\n')
# Out:
# ...
# Accuracy: 0.77
# ...

# %%
from sklearn.neighbors import KNeighborsRegressor
reg2 = KNeighborsRegressor(n_neighbors=2)
reg2.fit(X,y)
plt.scatter(X,y,c='orange',edgecolor='k')
plt.plot(z, reg2.predict(z),c='k',linewidth=3)
plt.title('KNN Rregressor: n_neighbors=2')
plt.show()

# %%
print('\n\n\n')
print('==================')
print('Accuracy: {:.2f}'.format(reg2.score(X,y)))
print('==================')
print('\n\n\n')
# Out:
# ...
# Accuracy: 0.86
# ...

# %%
from sklearn.datasets import load_wine
wine_dataset = load_wine()

# %%
print('\n\n\n')
print('result:')
print('============')
print("keys:\n{}".format(wine_dataset.keys()))
print('============')
print('\n\n\n')
# Out:
# result:
# ...
# keys:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])
# ...

# %%
print('\n\n\n')
print('result')
print('=========')
print("dataset shape:{}".format(wine_dataset['data'].shape))
print('=========')
print('\n\n\n')
# Out:
# result
# ...
# dataset shape:(178, 13)
# ...

# %%
print(wine_dataset['DESCR'])
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(wine_dataset['data'],wine_dataset['target'],random_state=0)
print('\n\n\n')
print('result')
print('=========\n')
print('X_train shape:{}'.format(X_train.shape))
print('X_test shape:{}'.format(X_test.shape))
print('y_train shape:{}'.format(y_train.shape))
print('y_test.shape:{}'.format(y_test.shape))
print('\n=========')
print('\n\n\n')
# Out:
# result
# ...
#
# X_train shape:(133, 13)
# X_test shape:(45, 13)
# y_train shape:(133,)
# y_test.shape:(45,)
#
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=1)
print('\n\n\n')
print('result')
print('========\n')
knn.fit(X_train,y_train)
print(knn)
print('\n========')
print('\n\n\n')
# Out:
# result
# ...
#
# KNeighborsClassifier(n_neighbors=1)
#
# ...

# %%
print('\n\n\n')
print('result')
print('========\n')
print('scores:{:.2f}'.format(knn.score(X_test,y_test)))
print('\n========')
print('\n\n\n')
# Out:
# result
# ...
#
# scores:0.76
#
# ...

# %%
import numpy as np
X_new = np.array([[13.2,2.77,2.51,18.5,96.6,1.04,2.55,0.57,1.47,6.2,1.05,3.33,820]])
prediction = knn.predict(X_new)
print('\n\n\n')
print('result:')
print('========\n')
print("predicted classification:{}".format(wine_dataset['target_names'][prediction]))
print('\n========')
print('\n\n\n')
# Out:
# result:
# ...
#
# predicted classification:['class_2']
#
# ...
